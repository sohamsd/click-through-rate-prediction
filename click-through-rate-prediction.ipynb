# %% [markdown]
# **Creating a model that will predict whether or not users will click on an ad based on features of that user with the highest accuracy.**
#
# This data set contains the following features:
#
# * 'Daily Time Spent on Site': consumer time on site in minutes
# * 'Age': cutomer age in years
# * 'Area Income': Avg. Income of geographical area of consumer
# * 'Daily Internet Usage': Avg. minutes a day consumer is on the internet
# * 'Ad Topic Line': Headline of the advertisement
# * 'City': City of consumer
# * 'Male': Whether or not consumer was male
# * 'Country': Country of consumer
# * 'Timestamp': Time at which consumer clicked on Ad or closed window
# * 'Clicked on Ad': 0 or 1 indicated clicking on Ad

# %% [markdown]
# # Importing  Required Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# machine learning algorithms
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# # Loading the Data

# %%
ad_data=pd.read_csv("advertising.csv ")

# %%
sns.FacetGrid(ad_data, hue="Clicked on Ad", height=5) \
   .map(sns.distplot,"Area Income" ) \
   .add_legend();
plt.show();

# %%
ad_data
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# 5                       59.99   23     59761.56                226.74
# 6                       88.91   33     53852.85                208.36
# 7                       66.00   48     24593.33                131.76
# 8                       74.53   30     68862.00                221.51
# 9                       69.88   20     55642.32                183.82
# 10                      47.64   49     45632.51                122.02
# 11                      83.07   37     62491.01                230.87
# ...

# %%
ad_data.describe()
# Out:
#        Daily Time Spent on Site          Age   Area Income  \
# count               1000.000000  1000.000000   1000.000000
# mean                  65.000200    36.009000  55000.000080
# std                   15.853615     8.785562  13414.634022
# min                   32.600000    19.000000  13996.500000
# 25%                   51.360000    29.000000  47031.802500
# 50%                   68.215000    35.000000  57012.300000
# 75%                   78.547500    42.000000  65470.635000
# max                   91.430000    61.000000  79484.800000
#
#        Daily Internet Usage         Male  Clicked on Ad
# count           1000.000000  1000.000000     1000.00000
# mean             180.000100     0.481000        0.50000
# std               43.902339     0.499889        0.50025
# min              104.780000     0.000000        0.00000
# 25%              138.830000     0.000000        0.00000
# 50%              183.130000     0.000000        0.50000
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
#  ###  Creating a histograms for comparision  ###

# %% [markdown]
# #### Daily Time Spent on Site

# %%
sns.FacetGrid(ad_data, hue="Clicked on Ad", height=5) \
   .map(sns.distplot, 'Daily Time Spent on Site') \
   .add_legend();
plt.show();

# %% [markdown]
# #### Daily Internet Usage

# %%
sns.FacetGrid(ad_data, hue="Clicked on Ad", height=5) \
   .map(sns.distplot,"Daily Internet Usage" ) \
   .add_legend();
plt.show();

# %% [markdown]
# #### Age

# %%
sns.FacetGrid(ad_data, hue="Clicked on Ad", height=5) \
   .map(sns.distplot,"Age" ) \
   .add_legend();
plt.show();

# %%
sns.FacetGrid(ad_data, hue="Clicked on Ad", height=5) \
   .map(sns.distplot,"Area Income" ) \
   .add_legend();
plt.show();

# %% [markdown]
# ### Creating a jointplot showing Area Income versus Age.

# %%
sns.jointplot(x='Age', y='Area Income', data=ad_data, kind='scatter')

# %% [markdown]
# ### Creating a jointplot showing the kde distributions of Daily Time spent on site vs. Age.

# %%
sns.jointplot(x='Age', y='Daily Time Spent on Site', data=ad_data, kind='kde')
# kde: kenerl density estimation

# %% [markdown]
# ### Creating a jointplot of 'Daily Time Spent on Site' vs. 'Daily Internet Usage'

# %%
sns.jointplot(x='Daily Internet Usage', y='Daily Time Spent on Site', data=ad_data, kind='scatter')

# %% [markdown]
#  ### Creating a pairplot with the hue defined by the 'Clicked on Ad' column feature.

# %%
sns.pairplot(ad_data, hue='Clicked on Ad')
sns.set_style("whitegrid");
plt.show()
# Out:
# C:\Users\prafu\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\prafu\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %% [markdown]
# # Modelling and predicting with Machine Learning

# %% [markdown]
# The main goal of the entire project is to predict whether or not users will click on an ad  with the highest accuracy. In order to achieve this, we will test several classification algorithms. This section includes all results obtained from the study and introduces the best performer according to accuracy metric. We have chosen several algorithms typical for solving supervised learning problems throughout classification methods.

# %%
from sklearn.model_selection import train_test_split

# %%
ad_data.columns
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage', 'Ad Topic Line', 'City', 'Male', 'Country',
#        'Timestamp', 'Clicked on Ad'],
#       dtype='object')

# %%
X = ad_data[['Daily Time Spent on Site', 'Age', 'Area Income','Daily Internet Usage', 'Male']]
y = ad_data['Clicked on Ad']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# First of all, let's equip ourselves with a handy tool that benefits from the cohesion of SciKit Learn library and formulate a general function for training our models. The reason for displaying accuracy on both, train and test sets, is to allow us to evaluate whether the model overfits or underfits the data (so-called bias/variance tradeoff).

# %%
def train_model(X_train, y_train, X_test, y_test, classifier, **kwargs):
    
    """
    Fit the chosen model and print out the score.
    
    """
    
    # instantiate model
    model = classifier(**kwargs)
    
    # train model
    model.fit(X_train,y_train)
    
    # check accuracy and print out the results
    fit_accuracy = model.score(X_train, y_train)
    test_accuracy = model.score(X_test, y_test)
    
    print(f"Train accuracy: {fit_accuracy:0.2%}")
    print(f"Test accuracy: {test_accuracy:0.2%}")
    
    return model

# %% [markdown]
# ### K-Nearest Neighbours (KNN)
# K-Nearest Neighbors algorithm is a non-parametric method used for classification and regression. The principle behind nearest neighbour methods is to find a predefined number of training samples closest in distance to the new point and predict the label from these.

# %%
# KNN
model = train_model(X_train, y_train, X_test, y_test, KNeighborsClassifier)
# Out:
# Train accuracy: 81.49%
# Test accuracy: 69.39%

# %% [markdown]
# Test accuracy of KNN is just satisfactory. Let's see if KNN can perform even better by trying different 'n_neighbours' inputs.

# %%
# Seek optimal 'n_neighbours' parameter
for i in range(1,10):
    print("n_neigbours = "+str(i))
    train_model(X_train, y_train, X_test, y_test, KNeighborsClassifier, n_neighbors=i)
# Out:
# n_neigbours = 1
# Train accuracy: 100.00%
# Test accuracy: 76.36%
# n_neigbours = 2
# Train accuracy: 87.76%
# Test accuracy: 71.82%
# n_neigbours = 3
# Train accuracy: 86.57%
# Test accuracy: 70.91%
# n_neigbours = 4
# Train accuracy: 81.04%
# Test accuracy: 69.70%
# n_neigbours = 5
# Train accuracy: 81.49%
# Test accuracy: 69.39%
# n_neigbours = 6
# Train accuracy: 80.45%
# Test accuracy: 68.79%
# n_neigbours = 7
# Train accuracy: 79.70%
# Test accuracy: 68.48%
# n_neigbours = 8
# Train accuracy: 78.51%
# Test accuracy: 68.79%
# n_neigbours = 9
# Train accuracy: 78.06%
# Test accuracy: 69.09%

# %% [markdown]
# We get better result than previous by taking n_neigbours = 1.

# %% [markdown]
# ## Decision Trees
#
#    DT algorithm creates a model that predicts the value of a target variable by learning simple decision rules inferred from the data features. It is simple to understand and interpret and it's possible to visualize how important a particular feature was for our tree.

# %%
# Decision Tree
model = train_model(X_train, y_train, X_test, y_test, DecisionTreeClassifier, random_state=2606)

# plot feature importances
pd.Series(model.feature_importances_,X.columns).sort_values(ascending=True).plot.barh()
# Out:
# Train accuracy: 100.00%
# Test accuracy: 93.94%

# %% [markdown]
# Variable 'Daily internet Usage' turns out to be a significantly important feature.
# Decision tree model learns the train set perfectly.
# With impressive accuracy of almost 94%, Decision Tree is taking the lead!

# %% [markdown]
# ## Logistic Regression
#
# Logistic regression is a basic technique in statistical analysis that attempts to predict a data value based on prior observations. A logistic regression algorithm looks at the relationship between a dependent variable and one or more dependent variables.

# %%
# Logistic Regression
model = train_model(X_train, y_train, X_test, y_test, LogisticRegression)
# Out:
# Train accuracy: 90.00%
# Test accuracy: 90.91%
# C:\Users\prafu\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# Negligible difference between train and test score tells us as that model performs at the optimal level. Although the result itself is slightly lower than Decision Tree, yet it is quite good.

# %% [markdown]
# ## Gaussian Naive Bayes
# In machine learning, naive Bayes classifiers are a family of simple probabilistic classifiers based on applying Bayes' theorem with strong (naive) independence assumptions between the features.

# %%
#Gaussian Naive Bayes
model = train_model(X_train, y_train, X_test, y_test, GaussianNB)
# Out:
# Train accuracy: 96.57%
# Test accuracy: 96.06%

# %% [markdown]
# Negligible difference between train and test score tells us as that model performs at the optimal level. Accuracy of Gaussian Naive Bayes is better than Decision Tree and it is best so far.

# %% [markdown]
# ## Support Vector Machines
# Support Vector Machines are perhaps one of the most popular machine learning algorithms. They are the go-to method for a high-performing algorithm with a little tuning. At first, let's try it on default settings.

# %%
# Support Vector Machines
model = train_model(X_train, y_train, X_test, y_test, SVC)
# Out:
# C:\Users\prafu\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# Train accuracy: 100.00%
# Test accuracy: 49.09%

# %%
# tuned SVM
model = train_model(X_train, y_train, X_test, y_test, SVC, C=0.05, kernel='linear')
# Out:
# Train accuracy: 97.31%
# Test accuracy: 95.45%

# %% [markdown]
# Training accuracy of SVM is better than Gaussian Naive Bayes but test accuracy of Gaussian Naive Bayes is slightli better than SVM

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The goal of the project was to compare different machine learning algorithms and predict if a certain person, given various personal features of that user, will click on an ad or not. Here are the final results.

# %%
# initialize an empty list
accuracy = []

# list of algorithms names
classifiers = ['KNN', 'Decision Trees', 'Logistic Regression', 'Naive Bayes', 'SVM']

# list of algorithms with parameters
models = [KNeighborsClassifier(n_neighbors=5), DecisionTreeClassifier(max_depth=6, random_state=2606), LogisticRegression(), 
        GaussianNB(), SVC(C=0.05, kernel='linear'),]

# loop through algorithms and append the score into the list
for i in models:
    model = i
    model.fit(X_train, y_train)
    score = model.score(X_test, y_test)
    accuracy.append(score)
# Out:
# C:\Users\prafu\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
# create a dataframe from accuracy results
summary = pd.DataFrame({'accuracy':accuracy}, index=classifiers)       
summary
# Out:
#                      accuracy
# KNN                  0.693939
# Decision Trees       0.939394
# Logistic Regression  0.909091
# Naive Bayes          0.960606
# SVM                  0.954545

# %% [markdown]
# ### Naive Bayes	algorithm give highest accuracy.
